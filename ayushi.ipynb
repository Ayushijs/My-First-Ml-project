# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#imporing the dataset
dataset = pd.read_csv('Iris.csv')

# %%
#showing the dataset
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#show columns
dataset.columns

#showing the shape of the dataset
dataset.shape
# Out:
# (150, 6)

# %%
#show index
dataset.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
#plot pie chart
dataset['Species'].value_counts().plot(kind='pie', autopct='%.2f%%', figsize=(6, 6))
plt.title("Pie chart of Species")
plt.show()

# %%
#plotting the dataset
plt.scatter(dataset['SepalLengthCm'],dataset['SepalWidthCm'],dataset['PetalLengthCm'],dataset['PetalWidthCm'])
plt.show()

# %%
#splitting the dataset into dependent and independent variables
x = dataset.iloc[:,1:5].values
y = dataset.iloc[:,5].values

# %%
#splitting the dataset into training and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25)

# %%
#model building
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#predicting the test set results
y_pred = classifier.predict(x_test)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

# %%
#accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9736842105263158

# %%
#testing the model
x_test = np.array([[5.1,3.5,1.4,0.2]])
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# ['Iris-setosa']

# %%
#plotting the dataset
plt.bar(dataset['SepalLengthCm'],dataset['SepalWidthCm'],dataset['PetalLengthCm'],dataset['PetalWidthCm'])
# Out:
# <BarContainer object of 150 artists>
